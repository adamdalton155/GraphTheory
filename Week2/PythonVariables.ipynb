# %%
i = 1

f = 1.0

c = 'c'

s = "Hello, world!"

t = "I can't believe it!"

u = 'Ian says "hello"'

# %%
i
# Out:
# 1

# %%
f
# Out:
# 1.0

# %%
c
# Out:
# 'c'

# %%
s
# Out:
# 'Hello, world!'

# %%
type(i)
# Out:
# int

# %%
type(f)
# Out:
# float

# %%
i + i
# Out:
# 2

# %%
f + f
# Out:
# 2.0

# %%
u
# Out:
# 'Ian says "hello"'

# %%
u
# Out:
# 'Ian says "hello"'

# %%
s
# Out:
# 'Hello, world!'

# %%
t
# Out:
# "I can't believe it!"
