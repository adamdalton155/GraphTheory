# %% [markdown]
# <h1>Log n</h1>
# <hr>

# %% [markdown]
# $ 2^4 = 2 \times 2 \times 2 \times 2 = 16$
#
# $ 2^{-4} = \frac{1}{2^4}$
#
# $ 2^4 \times{-4} = 2^{4+(-4)} = 2^{1} $
#
# $ 2^{0.5}  = \sqrt{2} $

# %%
2**4
# Out:
# 16

# %%
2**(-4)
# Out:
# 0.0625

# %%
2**(0.5)
# Out:
# 1.4142135623730951

# %% [markdown]
# <br>
# $ b^a = n \leftrightarrow \log n = a $
#
# $2^4 = 16 \leftrightarrow \log_2 16 = 4 $

# %%
import math

# %%
math.log(16,2)
# Out:
# 4.0
